# %% [markdown]
# Sort an Array of 0s, 1s, and 2s

# %%
class Solution:
    def sort012(self, arr):
        # code here
        zeroes = arr.count(0)
        ones = arr.count(1)
        twos = arr.count(2)
        
        arr.clear()
        for x in range(zeroes):
            arr.append(0)
        for x in range(ones):
            arr.append(1)
        for x in range(twos):
            arr.append(2)
            
        # this works, but i don't like the fact that it only works for 0s, 1s, and 2s.
        # i need to relearn how to do sorting algorithms, apparently.

# %% [markdown]
# Binary Search
